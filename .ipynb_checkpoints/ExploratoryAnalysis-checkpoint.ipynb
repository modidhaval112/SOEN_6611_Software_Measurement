# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('darkgrid')

import functions

# %%
mockito = functions.process_project_data('mockito',exploratory=True)
wildfly = functions.process_project_data('wildfly',exploratory=True)

# %% [markdown]
# ### Exploring outliers :

# %%
mockito = functions.limit_data_dict(dic=mockito,value=10,)

# %% [markdown]
# initial = 9764
# WMC : outlier of 1428, 75% = 2 , 7879 ,2
# RFC : outlier of 113,  75% = 0 , 7524 ,1
# LCOM: outlier of 100,  75% = 0 , 7496 ,1
# NOC : outlier of 53,   75% = 0 , 7371 ,1
# CBO : outlier of 6,    75% = 0 , 7206 ,1
# DIT : outlier of 5,    75% = 0 , 7194 ,2 becase the data decreased by 300 which was a major change
# CYCLOMATIC : outlier of 2, 75% = 1 ,  ,2

# %%
mockito = functions.limit_data_eachcol_dict(col="wmc",dic=mockito,value=2)
mockito = functions.limit_data_eachcol_dict(col="rfc",dic=mockito,value=1)
mockito = functions.limit_data_eachcol_dict(col="lcom",dic=mockito,value=1)
mockito = functions.limit_data_eachcol_dict(col="noc",dic=mockito,value=1)
mockito = functions.limit_data_eachcol_dict(col="cbo",dic=mockito,value=1)
mockito = functions.limit_data_eachcol_dict(col="dit",dic=mockito,value=2)

# %%
mockito = functions.limit_data_eachcol_dict(col="cyclomatic",dic=mockito,value=1)

# %%
for ver in mockito:
    print(mockito[ver].describe())
# Out:
#                cbo          noc   cyclomatic          dit    lcom  \
# count  7194.000000  7194.000000  7194.000000  7194.000000  7194.0
# mean      0.015430     0.010147     0.838198     0.125660     0.0
# std       0.123262     0.100229     0.590210     0.383593     0.0
# min       0.000000     0.000000     0.000000     0.000000     0.0
# 25%       0.000000     0.000000     0.000000     0.000000     0.0
# 50%       0.000000     0.000000     1.000000     0.000000     0.0
# 75%       0.000000     0.000000     1.000000     0.000000     0.0
# max       1.000000     1.000000     2.000000     2.000000     0.0
#
#                rfc          wmc   code_smell          bug
# count  7194.000000  7194.000000  7194.000000  7194.000000
# mean      0.041006     0.906172     0.074229     0.040311
# std       0.198319     0.573969     0.693795     0.196702
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     1.000000     0.000000     0.000000
# 50%       0.000000     1.000000     0.000000     0.000000
# 75%       0.000000     1.000000     0.000000     0.000000
# max       1.000000     2.000000    16.000000     1.000000
#                cbo          noc          rfc   cyclomatic          dit  \
# count  6800.000000  6800.000000  6800.000000  6800.000000  6800.000000
# mean      0.015147     0.009706     0.039559     0.843382     0.121029
# std       0.122147     0.098046     0.194935     0.592422     0.374859
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     1.000000     0.000000
# 75%       0.000000     0.000000     0.000000     1.000000     0.000000
# max       1.000000     1.000000     1.000000     2.000000     2.000000
#
#          lcom          wmc   code_smell          bug
# count  6800.0  6800.000000  6800.000000  6800.000000
# mean      0.0     0.913088     0.073382     0.040294
# std       0.0     0.576241     0.699461     0.196663
# min       0.0     0.000000     0.000000     0.000000
# 25%       0.0     1.000000     0.000000     0.000000
# 50%       0.0     1.000000     0.000000     0.000000
# 75%       0.0     1.000000     0.000000     0.000000
# max       0.0     2.000000    16.000000     1.000000
#                cbo          noc          rfc   cyclomatic          dit  \
# count  6917.000000  6917.000000  6917.000000  6917.000000  6917.000000
# mean      0.015903     0.009542     0.040046     0.842996     0.121151
# std       0.125109     0.097222     0.196082     0.588532     0.376522
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     1.000000     0.000000
# 75%       0.000000     0.000000     0.000000     1.000000     0.000000
# max       1.000000     1.000000     1.000000     2.000000     2.000000
#
#          lcom          wmc   code_smell          bug
# count  6917.0  6917.000000  6917.000000  6917.000000
# mean      0.0     0.911378     0.073876     0.040769
# std       0.0     0.571984     0.695691     0.197769
# min       0.0     0.000000     0.000000     0.000000
# 25%       0.0     1.000000     0.000000     0.000000
# 50%       0.0     1.000000     0.000000     0.000000
# 75%       0.0     1.000000     0.000000     0.000000
# max       0.0     2.000000    16.000000     1.000000

# %%
for ver in mockito:
    print(ver)
    
    f,ax = plt.subplots(figsize=(10,9))
    #ax.set_ylim([0,60])
    df = mockito[ver]
    
    sns.boxplot(data=df)
    plt.show()
# Out:
# v25
# v17
# v21

# %% [markdown]
# ### Limiting data and reducing outliers

# %%
mockito = functions.limit_data_dict(mockito)
wildfly = functions.limit_data_dict(wildfly)

# %%
for ver in wildfly:
    print(ver)
    
    f,ax = plt.subplots(figsize=(10,9))
    #ax.set_ylim([0,60])
    df = wildfly[ver]
    
    sns.boxplot(data=df)
    plt.show()
# Out:
# v12
# v16
# v8

# %% [markdown]
# ## Plotting Heat Maps:
#
# ---
# ### Observations:
# <br>
# Following are the high correlations that we observe:
#
# - **Mockito:**
#     - __*>45% :*__
#         - CBO vs [RFC,DIT,LCOM]
#         - RFC vs [DIT]
# - **Wildfly:**
#     - __*>50% :*__
#         - CBO vs [RFC,DIT,LCOM]
#         - RFC vs [DIT]
#
#
# ---
# **WILDFLY HEATPLOTS**
#
# ---

# %%
functions.plot_heatMaps(df=wildfly)

# %% [markdown]
# **MOCKITO HEATPLOTS**
#
# ---

# %%
df = mockito['v25']
corr = df.corr()
sns.heatmap(corr)

# %%
functions.plot_heatMaps(df=mockito)

# %% [markdown]
# <br>
# <font size=4>Based on the variables we see having high correlations, we make regression plots to uncover the kind of correlation pattern they share.</font>
# </br>

# %% [markdown]
# # CBO VS [RFC , LCOM]

# %% [markdown]
# **MOCKITO REGRESSION PLOTS**
# - CBO VS RFC
# - CBO VS LCOM
# ---

# %%
x='cyclomatic'
y=['rfc']
functions.plot_regressions(data=mockito,proj_name='mockito',checkVar=x,vsVarList=y,ylim=60)

# %%
x='rfc'
y=['dit']
functions.plot_regressions(data=mockito,proj_name='mockito',checkVar=x,vsVarList=y,ylim=60)

# %%
x='cbo'
y=['rfc','lcom']
functions.plot_regressions(data=mockito,proj_name='mockito',checkVar=x,vsVarList=y,ylim=60)

# %% [markdown]
# **WILDFLY REGRESSION PLOTS**
# - CBO VS RFC
# - CBO VS LCOM
# ---

# %%
x = 'cbo'
y = ['rfc','lcom']
functions.plot_regressions(data=wildfly,proj_name='wildfly',checkVar=x,vsVarList=y)

# %% [markdown]
# # CBO VS DIT

# %% [markdown]
# **MOCKITO**

# %%
x = 'cbo'
y = ['dit']
functions.plot_regressions(data=mockito,proj_name='mockito',checkVar=x,vsVarList=y,ylim=100)

# %%
for ver in mockito:
    print(ver)
    f,ax = plt.subplots(figsize=(12,2))
    sns.pointplot(data=mockito['v21'],y='cbo',x='dit',color='g')
    plt.show()

# %% [markdown]
# **WILDFLY**

# %%
x = 'cbo'
y = ['dit']
functions.plot_regressions(data=wildfly,proj_name='wildfly',checkVar=x,vsVarList=y,ylim=100)

# %%
for ver in wildfly:
    print(ver)
    f,ax = plt.subplots(figsize=(12,2))
    sns.pointplot(data=wildfly[ver],y='cbo',x='dit',color='g',errwidth=False)
    plt.show()

# %% [markdown]
# # RFC VS DIT

# %% [markdown]
# **MOCKITO**

# %%
x = 'rfc'
y = ['dit']
functions.plot_regressions(data=mockito,proj_name='mockito',checkVar=x,vsVarList=y,ylim=200)

# %% [markdown]
# **WILDFLY**

# %%
x = 'rfc'
y = ['dit']
functions.plot_regressions(data=wildfly,proj_name='wildfly',checkVar=x,vsVarList=y,ylim=200)

# %%
df = mockito['v25']

# %%
def plot_metric_bug(df,kind='bar'):
    for col in df.columns:
        df.groupby(col)['bug'].count().plot(kind='bar')
        plt.show()

# %%
plot_metric_bug(df)

# %%
df.groupby('cbo')['bug'].count().plot(kind='bar')

# %%
df.groupby('dit')['bug'].count().plot(kind='bar')
